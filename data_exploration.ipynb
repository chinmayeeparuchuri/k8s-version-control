# %%
import pandas as pd

# Load AssureMOSS datasets
february_2022 = pd.read_csv('../data/assuremoss_dataset/elastic_february2022_data.csv')
may_2021_benign = pd.read_csv('../data/assuremoss_dataset/elastic_may2021_benign_data.csv')
may_2021_malicious = pd.read_csv('../data/assuremoss_dataset/elastic_may2021_malicious_data.csv')
may_2022 = pd.read_csv('../data/assuremoss_dataset/elastic_may2022_data.csv')

# Display dataset info
print("February 2022 Dataset:")
print(february_2022.info())
print(february_2022.head())

print("May 2021 Benign Dataset:")
print(may_2021_benign.info())
print(may_2021_benign.head())

print("May 2021 Malicious Dataset:")
print(may_2021_malicious.info())
print(may_2021_malicious.head())

print("May 2022 Dataset:")
print(may_2022.info())
print(may_2022.head())
# Out:
# February 2022 Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398414 entries, 0 to 398413
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   _source_flow_id            398414 non-null  object
#  1   _source_flow_final         398414 non-null  bool
#  2   _source_source_ip          398414 non-null  object
#  3   _source_destination_ip     398414 non-null  object
#  4   _source_network_bytes      398414 non-null  int64
#  5   _source_network_transport  396080 non-null  object
#  6   _source_@timestamp         398414 non-null  object
#  7   _source_event_duration     398414 non-null  int64
#  8   _source_destination_port   395857 non-null  float64
#  9   _source_source_port        395857 non-null  float64
#  10  label                      398414 non-null  object
# dtypes: bool(1), float64(2), int64(2), object(6)
# memory usage: 30.8+ MB
# None
# ...

# %%
# Load Horizontal Scaling datasets
test_jmeter = pd.read_csv('../data/horizontal_scaling_dataset/TestJMeterData.csv')
test_k8s = pd.read_csv('../data/horizontal_scaling_dataset/TestK8sData.csv')
train_data = pd.read_csv('../data/horizontal_scaling_dataset/TrainData.csv')

# Display dataset info
print("Test JMeter Dataset:")
print(test_jmeter.info())
print(test_jmeter.head())

print("Test K8s Dataset:")
print(test_k8s.info())
print(test_k8s.head())

print("Training Data:")
print(train_data.info())
print(train_data.head())
# Out:
# Test JMeter Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503960 entries, 0 to 503959
# Data columns (total 25 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   timeStamp          503960 non-null  object
#  1   elapsed            503960 non-null  int64
#  2   label              503960 non-null  object
#  3   responseCode       404348 non-null  float64
#  4   responseMessage    503960 non-null  object
#  5   threadName         503960 non-null  object
#  6   dataType           503960 non-null  object
#  7   success            503960 non-null  bool
#  8   bytes              503960 non-null  int64
#  9   sentBytes          503960 non-null  int64
#  10  grpThreads         503960 non-null  int64
#  11  allThreads         503960 non-null  int64
#  12  URL                503960 non-null  object
#  13  Latency            503960 non-null  int64
#  14  SampleCount        503960 non-null  int64
# ...
